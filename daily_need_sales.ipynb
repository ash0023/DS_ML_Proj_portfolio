# %% [markdown]
# <a href="https://colab.research.google.com/github/ash0023/DS_ML_Proj_portfolio/blob/main/daily_need_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install panda
# !pip install numpy
# Out:
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7255 sha256=5a34896645143ec13c66b97a9ed2a54d11b1e3402e9476f78cd1638317e4b977
#   Stored in directory: /root/.cache/pip/wheels/e6/3d/81/a3665ce657d35359ca337b1db2975dbe5cd281a88b8982f6b6
# Successfully built panda
# ...

# %%
import pandas as pd
import os
import numpy as np

# %%
files=[file for file in os.listdir('/Z/')]

all_months_data = pd.DataFrame()

for file in files:
  df=pd.read_csv('/Z/'+ file)
  all_months_data= pd.concat([all_months_data,df])

all_months_data.to_csv("all_data.csv", index= False)

# %%
all_data= pd.read_csv("all_data.csv")
all_data
# Out:
#        Order ID  ...                         Purchase Address
# 0        222910  ...          389 South St, Atlanta, GA 30301
# 1        222911  ...            590 4th St, Seattle, WA 98101
# 2        222912  ...           861 Hill St, Atlanta, GA 30301
# 3        222913  ...          190 Ridge St, Atlanta, GA 30301
# 4        222914  ...         824 Forest St, Seattle, WA 98101
# ...         ...  ...                                      ...
# 186845   259353  ...   840 Highland St, Los Angeles, CA 90001
# 186846   259354  ...  216 Dogwood St, San Francisco, CA 94016
# 186847   259355  ...     220 12th St, San Francisco, CA 94016
# 186848   259356  ...   511 Forest St, San Francisco, CA 94016
# 186849   259357  ...   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
all_data["Month"]= all_data["Order Date"].str[0:2]
all_data
# Out:
#        Order ID  ... Month
# 0        222910  ...    07
# 1        222911  ...    07
# 2        222912  ...    07
# 3        222913  ...    07
# 4        222914  ...    07
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [186850 rows x 7 columns]

# %%
nan_df= all_data[all_data.isna().any(axis=1)]
all_data= all_data.dropna(how='all')
all_data
# Out:
#        Order ID  ... Month
# 0        222910  ...    07
# 1        222911  ...    07
# 2        222912  ...    07
# 3        222913  ...    07
# 4        222914  ...    07
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [186305 rows x 7 columns]

# %%
all_data= all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data
# Out:
#        Order ID  ... Month
# 0        222910  ...    07
# 1        222911  ...    07
# 2        222912  ...    07
# 3        222913  ...    07
# 4        222914  ...    07
# ...         ...  ...   ...
# 186845   259353  ...    09
# 186846   259354  ...    09
# 186847   259355  ...    09
# 186848   259356  ...    09
# 186849   259357  ...    09
#
# [185950 rows x 7 columns]

# %%
all_data['Month']= all_data['Month'].astype('int32')
all_data['Quantity Ordered']= pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']= pd.to_numeric(all_data['Price Each'])
all_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
all_data['Sales']=all_data['Quantity Ordered']* all_data['Price Each']
all_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Order ID                   Product  ...  Month   Sales
# 0        222910  Apple Airpods Headphones  ...      7  150.00
# 1        222911             Flatscreen TV  ...      7  300.00
# 2        222912     AA Batteries (4-pack)  ...      7    3.84
# 3        222913     AA Batteries (4-pack)  ...      7    3.84
# 4        222914    AAA Batteries (4-pack)  ...      7   14.95
# ...         ...                       ...  ...    ...     ...
# 186845   259353    AAA Batteries (4-pack)  ...      9    8.97
# 186846   259354                    iPhone  ...      9  700.00
# ...

# %%
###Which month has the highest Sale?

# %%
results=all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months= range(1,13)

plt.bar(months, results['Sales'])
plt.xlabel('Months')
plt.ylabel('Sales Amount')
plt.title('Sales of 2019')
# Out:
# Text(0.5, 1.0, 'Sales of 2019')

# %%
###Which city has highest Sales?

# %%
def get_state(address):
  return address.split(",")[2].split(" ")[1]

all_data['City']= all_data['Purchase Address'].apply(lambda x: x.split(",")[1]+ " "+ get_state(x))
all_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#        Order ID                   Product  ...   Sales               City
# 0        222910  Apple Airpods Headphones  ...  150.00         Atlanta GA
# 1        222911             Flatscreen TV  ...  300.00         Seattle WA
# 2        222912     AA Batteries (4-pack)  ...    3.84         Atlanta GA
# 3        222913     AA Batteries (4-pack)  ...    3.84         Atlanta GA
# 4        222914    AAA Batteries (4-pack)  ...   14.95         Seattle WA
# ...         ...                       ...  ...     ...                ...
# 186845   259353    AAA Batteries (4-pack)  ...    8.97     Los Angeles CA
# ...

# %%
all_data['City'].unique()
# Out:
# array([' Atlanta GA', ' Seattle WA', ' San Francisco CA',
#        ' New York City NY', ' Los Angeles CA', ' Dallas TX', ' Boston MA',
#        ' Portland OR', ' Austin TX', ' Portland ME'], dtype=object)

# %%
results=all_data.groupby('City').sum()
results
# Out:
#                    Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta GA                   16602  2.779908e+06  104794  2.795499e+06
#  Austin TX                    11153  1.809874e+06   69829  1.819582e+06
#  Boston MA                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas TX                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles CA               33289  5.421435e+06  208325  5.452571e+06
#  New York City NY             27932  4.635371e+06  175741  4.664317e+06
#  Portland ME                   2750  4.471893e+05   17144  4.497583e+05
#  Portland OR                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco CA             50239  8.211462e+06  315520  8.262204e+06
#  Seattle WA                   16553  2.733296e+06  104941  2.747755e+06

# %%
cities= [city for city, df in all_data.groupby('City')]
plt.bar(cities, results['Sales'])
plt.xticks(cities, rotation="vertical",size=8)
plt.xlabel('Cities')
plt.ylabel("Total Sales")
plt.title("Sales as per Cities")
# Out:
# Text(0.5, 1.0, 'Sales as per Cities')

# %%
 ###Best time to display advertisment?

# %%
all_data["Order Date"]= pd.to_datetime(all_data['Order Date'])
all_data["Hour"]= all_data['Order Date'].dt.hour
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
all_data.head()
# Out:
#   Order ID                   Product  ...         City  Hour
# 0   222910  Apple Airpods Headphones  ...   Atlanta GA    16
# 1   222911             Flatscreen TV  ...   Seattle WA     8
# 2   222912     AA Batteries (4-pack)  ...   Atlanta GA    12
# 3   222913     AA Batteries (4-pack)  ...   Atlanta GA    10
# 4   222914    AAA Batteries (4-pack)  ...   Seattle WA     2
#
# [5 rows x 10 columns]

# %%
hours= [hours for hours, df in all_data.groupby("Hour")]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours)
plt.grid()
plt.show()

# %%
import seaborn as sns

# %%
all_data
# Out:
#        Order ID                   Product  ...               City  Hour
# 0        222910  Apple Airpods Headphones  ...         Atlanta GA    16
# 1        222911             Flatscreen TV  ...         Seattle WA     8
# 2        222912     AA Batteries (4-pack)  ...         Atlanta GA    12
# 3        222913     AA Batteries (4-pack)  ...         Atlanta GA    10
# 4        222914    AAA Batteries (4-pack)  ...         Seattle WA     2
# ...         ...                       ...  ...                ...   ...
# 186845   259353    AAA Batteries (4-pack)  ...     Los Angeles CA    20
# 186846   259354                    iPhone  ...   San Francisco CA    16
# 186847   259355                    iPhone  ...   San Francisco CA     7
# 186848   259356    34in Ultrawide Monitor  ...   San Francisco CA    17
# 186849   259357      USB-C Charging Cable  ...   San Francisco CA     0
#
# [185950 rows x 10 columns]

# %%
### What Products are most sold together?

# %%
s=all_data['Product'].unique()
np.count_nonzero(s)
# Out:
# 19

# %%
prd_data = all_data.sort_values(by=[ 'Order Date', 'Purchase Address'])
prd_data.head(5)
# Out:
#        Order ID                   Product  ...               City  Hour
# 146668   147268          Wired Headphones  ...   New York City NY     3
# 147478   148041      USB-C Charging Cable  ...   San Francisco CA     3
# 148831   149343  Apple Airpods Headphones  ...   New York City NY     4
# 149485   149964    AAA Batteries (4-pack)  ...          Dallas TX     5
# 148838   149350      USB-C Charging Cable  ...         Atlanta GA     6
#
# [5 rows x 10 columns]

# %%
df=all_data[all_data['Order ID'].duplicated(keep= False)]
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
df= df[['Order ID','Grouped']].drop_duplicates()
df.head(100)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Order ID                                            Grouped
# 118    223028  Vareebadd Phone,USB-C Charging Cable,Wired Hea...
# 140    223048               Vareebadd Phone,USB-C Charging Cable
# 188    223095     Apple Airpods Headphones,AA Batteries (4-pack)
# 201    223106                   Wired Headphones,Vareebadd Phone
# 213    223117                  Google Phone,USB-C Charging Cable
# ...       ...                                                ...
# 2782   225578                  Google Phone,USB-C Charging Cable
# 2879   225674  Bose SoundSport Headphones,Bose SoundSport Hea...
# ...

# %%
from itertools import combinations
from collections import Counter

count= Counter()
for row in df['Grouped']:
  row_list = row.split(',')
  count.update(Counter(combinations(row_list, 3)))

count.most_common(10)
# Out:
# [(('Google Phone', 'USB-C Charging Cable', 'Wired Headphones'), 87),
#  (('iPhone', 'Lightning Charging Cable', 'Wired Headphones'), 62),
#  (('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones'), 47),
#  (('Google Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones'), 35),
#  (('Vareebadd Phone', 'USB-C Charging Cable', 'Wired Headphones'), 33),
#  (('iPhone', 'Apple Airpods Headphones', 'Wired Headphones'), 27),
#  (('Google Phone', 'Bose SoundSport Headphones', 'Wired Headphones'), 24),
#  (('Vareebadd Phone', 'USB-C Charging Cable', 'Bose SoundSport Headphones'),
#   16),
#  (('Vareebadd Phone', 'Bose SoundSport Headphones', 'Wired Headphones'), 5),
#  (('USB-C Charging Cable', 'Bose SoundSport Headphones', 'Wired Headphones'),
#   5)]

# %%
###Which product sold up the most?

# %%
product_grp= all_data.groupby('Product')
quantity_grp=product_grp.sum()

products= [product for product, df in product_grp]
plt.bar(products,quantity_grp['Quantity Ordered'])
plt.xticks(products, rotation="vertical",size=8)
plt.xlabel('products')
plt.ylabel("Total Sales")
plt.title("Sales as ")
# Out:
# Text(0.5, 1.0, 'Sales as ')

# %%
prices= all_data.groupby('Product').mean()['Price Each']
fig, ax1 = plt.subplots()

ax2= ax1.twinx()
ax1.bar(products, quantity_grp['Quantity Ordered'],color='r')
ax2.plot(products,prices,color='b')



ax1.set_xlabel('Prpduct Names')
ax1.set_ylabel("Quantity")
ax2.set_ylabel('Pricing($)' )
ax1.set_xticklabels(products, rotation="vertical",size=8)
# Out:
# [Text(0, 0, '20in Monitor'),
#  Text(0, 0, '27in 4K Gaming Monitor'),
#  Text(0, 0, '27in FHD Monitor'),
#  Text(0, 0, '34in Ultrawide Monitor'),
#  Text(0, 0, 'AA Batteries (4-pack)'),
#  Text(0, 0, 'AAA Batteries (4-pack)'),
#  Text(0, 0, 'Apple Airpods Headphones'),
#  Text(0, 0, 'Bose SoundSport Headphones'),
#  Text(0, 0, 'Flatscreen TV'),
#  Text(0, 0, 'Google Phone'),
#  Text(0, 0, 'LG Dryer'),
#  Text(0, 0, 'LG Washing Machine'),
#  Text(0, 0, 'Lightning Charging Cable'),
#  Text(0, 0, 'Macbook Pro Laptop'),
#  Text(0, 0, 'ThinkPad Laptop'),
#  Text(0, 0, 'USB-C Charging Cable'),
#  Text(0, 0, 'Vareebadd Phone'),
#  Text(0, 0, 'Wired Headphones'),
#  Text(0, 0, 'iPhone')]
